# %% [markdown]
# # Assignment Questions

# %% [markdown]
# 1.Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss
# nominal, ordinal, interval, and ratio scales.
# - Qualitative Data (Categorical Data)
#
#   - Qualitative data represents characteristics or attributes that do not involve numerical values. This type of data is often descriptive and can be divided into categories.
#
# - Examples of Qualitative Data:
#   - Hair color: Black, blonde, brown
#
#   - Marital status: Single, married, divorced
#
#   - Types of vehicles: Sedan, SUV, truck
#
# - Quantitative Data (Numerical Data)
#   - Quantitative data consists of numerical values that can be measured or counted. This type of data is used for mathematical computations.
#
#     - Examples of Quantitative Data:
#       - Height of individuals: 5.8 feet, 6.2 feet
#
#       - Temperature: 25°C, 30°C
#
#       - Number of books on a shelf: 10, 15, 20
#
# - Measurement Scales of Data
#   - Quantitative and qualitative data are classified into four levels of measurement: nominal, ordinal, interval, and ratio scales.
#
# - 1.Nominal Scale (Qualitative)
#   - The simplest level of measurement.
#
#   - Data is categorized without any order or ranking.
#
#   - No numerical significance.
#
# - Examples:
#   - Gender (Male, Female, Non-binary)
#
#   - Eye color (Brown, Blue, Green)
#
#   - Blood type (A, B, AB, O)
#
# - Ordinal Scale (Qualitative)
#   - Data is categorized with a meaningful order or ranking.
#
# - Differences between ranks are not necessarily equal.
#
# - Examples:
#   - Education level (High school, Bachelor’s, Master’s, Ph.D.)
#
#   - Customer satisfaction (Dissatisfied, Neutral, Satisfied)
#
#   - Finishing position in a race (1st, 2nd, 3rd)
#
# - Interval Scale (Quantitative)
#   - Numerical data where the difference between values is meaningful.
#
#   - No true zero point (zero does not mean absence of the attribute).
#
# - Examples:
#   - Temperature in Celsius or Fahrenheit (0°C does not mean no temperature)
#
#   - IQ scores (an IQ of 0 does not mean no intelligence)
#
#   - Years on a calendar (2000, 2024)
#
# - Ratio Scale (Quantitative)
#   - The highest level of measurement.
#
# - Has a true zero point, meaning zero represents the total absence of the attribute.
#
#   - Allows for meaningful ratios (e.g., twice as much).
#
# - Examples:
#   - Weight (0 kg means no weight)
#
#   - Height (0 cm means no height)
#
#   - Income (0 dollars means no money)

# %% [markdown]
# 2.What are the measures of central tendency, and when should you use each? Discuss the mean, median,
# and mode with examples and situations where each is appropriate
# - Measures of central tendency summarize a dataset by identifying a central value around which data points are distributed. The three main measures are mean, median, and mode. Each measure is useful in different situations.
#
# Mean (Average)
# The mean is the sum of all values divided by the total number of values. It is best used when data is normally distributed (i.e., not skewed).
#
# - Formula:
#   - Mean
# =
# ∑
# 𝑋
# 𝑁
# Mean=
# N
# ∑X
# ​
#
# Where:
#
# 𝑋
# - X represents data values
#
# 𝑁
# - N is the total number of values
#
# - Example:
#   - The scores of five students in a test: 75, 80, 85, 90, 95
#
# Mean
# =
# 75
# +
# 80
# +
# 85
# +
# 90
# +
# 95
# 5
# =
# 85
# - Mean=
# 5
# 75+80+85+90+95
# ​
#  =85
# When to Use the Mean:
# When data is normally distributed (e.g., height, weight, exam scores).
#
# When there are no extreme outliers, as outliers can significantly distort the mean.
#
# When NOT to Use the Mean:
# When the data is skewed (e.g., income distribution where a few very high incomes can inflate the average).
#
# When there are outliers (e.g., house prices in a city with a few luxury homes).
#
#
# - Median
#   - The median is the middle value when data is arranged in order. It is best used when data is skewed or has outliers.
#
# - Example:
#   - Data set: 20, 22, 25, 30, 90
#
# - Ordered: 20, 22, 25, 30, 90
#
# - Middle value = 25 (Median)
#
# - When to Use the Median:
#   - When data is skewed (e.g., household income, where a few very high values may distort the mean).
#
# - When there are outliers (e.g., property prices in a region).
#
# - When NOT to Use the Median:
#   - When the data set is small and normally distributed, as the mean would be more informative.
#
# - When comparing datasets where mean values provide more meaningful differences.
#
#
# - Mode
#   - The mode is the most frequently occurring value in a dataset. A dataset can have one mode (unimodal), multiple modes (bimodal/multimodal), or no mode if all values are unique.
#
# - Example:
#   - Data set: 4, 5, 6, 6, 7, 8, 6, 9
#
# - Mode = 6 (since it appears most frequently)
#
# - When to Use the Mode:
# When dealing with categorical data (e.g., most common blood type in a population).
#
# When identifying the most popular choice (e.g., the most purchased product).
#
# When analyzing discrete numerical data (e.g., shoe sizes, where averages may not make sense).
#
# When NOT to Use the Mode:
# When data is continuous and the mode does not provide meaningful insights.
#
# When data is evenly distributed without clear frequent values.

# %% [markdown]
# 3.Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?
# - Dispersion refers to the spread or variability of a dataset. It helps determine how much the data deviates from the central tendency (mean, median, or mode). Understanding dispersion is crucial in statistics because two datasets with the same mean can have different levels of variability.
#
# - Common Measures of Dispersion:
#   -Range: The difference between the maximum and minimum values.
#
#   - Variance: Measures the average squared deviation from the mean.
#
#   - Standard Deviation: The square root of variance, showing spread in the same units as the data.
#
# - How Variance and Standard Deviation Measure Spread
#   - Larger variance/standard deviation → Greater spread (data points are farther from the mean).
#
#   - Smaller variance/standard deviation → Less spread (data points are closer to the mean).
#
# - Comparison Example:
#   - Dataset A: 10, 12, 14 (small spread, low standard deviation)
#   - Dataset B: 5, 20, 35 (large spread, high standard deviation)
#
# - Even if both datasets have the same mean, B has a higher standard deviation, indicating greater variability.
#
# - When to Use Each Measure
#   - Variance: Used in theoretical statistics (e.g., probability distributions).
#
#   - Standard Deviation: Preferred in practical applications (e.g., finance, quality control) since it has the same unit as the data.

# %% [markdown]
# 4.What is a box plot, and what can it tell you about the distribution of data?
# - A box plot is a graphical representation of a dataset’s distribution that shows its spread, skewness, and presence of outliers. It summarizes data using five key statistics called the five-number summary:
#
#   - Minimum – The smallest data value (excluding outliers)
#
#   - First Quartile (Q1) – The 25th percentile (lower quartile)
#
#   - Median (Q2) – The 50th percentile (middle value)
#
#   - Third Quartile (Q3) – The 75th percentile (upper quartile)
#
#   - Maximum – The largest data value (excluding outliers)
#
# - Key Features of a Box Plot
#   - Box: Represents the interquartile range (IQR), which is the middle 50% of the data (
# 𝑄
# 3
# −
# 𝑄
# 1
# Q3−Q1).
#
#   - Whiskers: Extend from the box to the minimum and maximum values within 1.5 times the IQR.
#
#   - Outliers: Points beyond the whiskers, often plotted individually.
#
#   - Median Line: A horizontal line inside the box, indicating the dataset's central tendency.

# %% [markdown]
# 5.Discuss the role of random sampling in making inferences about populations.
# - Random sampling is a method of selecting a subset of individuals from a larger population where every member has an equal chance of being chosen. It is a fundamental technique in statistical inference, helping researchers draw conclusions about an entire population based on a smaller, manageable sample.
#
# - Why is Random Sampling Important?
#   - Reduces Bias
#
#     - Ensures that the sample represents the population fairly.
#
#     - Avoids systematic favoritism toward specific groups.
#
# - Increases Accuracy
#
#   - Provides a better approximation of the true population characteristics.
#
#   - Prevents misleading conclusions that might arise from non-random sampling.
#
# - Enables Generalization
#
#   - Findings from the sample can be extrapolated to the entire population.
#
#   - Allows researchers to make valid inferences about trends, behaviors, or characteristics.
#
# - Supports Statistical Tests
#
#   - Many statistical methods (e.g., confidence intervals, hypothesis testing) require random sampling to produce valid results.

# %% [markdown]
# 6.Explain the concept of skewness and its types. How does skewness affect the interpretation of data?
# - Skewness measures the asymmetry of a dataset’s distribution. It indicates whether the data is symmetrically distributed around the mean or if it is shifted more toward one side.
#
#   - Symmetric Distribution: If a dataset has no skew, the mean, median, and mode are equal, and the distribution is bell-shaped (like a normal distribution).
#
#   - Skewed Distribution: If the data is not symmetrical, it is skewed either to the left or right.
#
# - Types of Skewness
#   - 1.Positive Skew (Right-Skewed Distribution)
#     - The right tail of the distribution is longer.
#
#     - Mean > Median > Mode (the mean is pulled toward larger values).
#
#     - Indicates higher frequency of lower values with a few very large values (outliers).
#
# - Examples:
#   - Income distribution (most people earn a lower income, but a few earn extremely high salaries).
#
#   - Real estate prices (most houses are affordable, but a few luxury homes increase the average price).
#
# - Negative Skew (Left-Skewed Distribution)
#   - The left tail of the distribution is longer.
#
#   - Mean < Median < Mode (the mean is pulled toward smaller values).
#
#   - Indicates higher frequency of larger values with a few very small values (outliers).
#
# - Examples:
#   - Age at retirement (most people retire around the same age, but a few retire very early, lowering the mean).
#
#   - Exam scores (if most students score high, but a few fail with very low scores).

# %% [markdown]
# 7.What is the interquartile range (IQR), and how is it used to detect outliers?
# - The Interquartile Range (IQR) measures the spread of the middle 50% of a dataset. It is calculated as:
#
# 𝐼
# 𝑄
# 𝑅
# =
# 𝑄
# 3
# −
# 𝑄
# 1
# IQR=Q3−Q1
# Where:
#
# Q1 (First Quartile, 25th percentile): The median of the lower half of the data.
#
# Q3 (Third Quartile, 75th percentile): The median of the upper half of the data.
#
# IQR: Represents the range in which the middle 50% of data points lie.
#
# - How is IQR Used to Detect Outliers?
#   - Outliers are extreme values that fall far outside the main distribution. The IQR method identifies outliers using the 1.5 × IQR Rule:
#
# Lower Bound
# =
# 𝑄
# 1
# −
# 1.5
# ×
# 𝐼
# 𝑄
# 𝑅
# Lower Bound=Q1−1.5×IQR
# Upper Bound
# =
# 𝑄
# 3
# +
# 1.5
# ×
# 𝐼
# 𝑄
# 𝑅
# Upper Bound=Q3+1.5×IQR
# Any data point below the Lower Bound or above the Upper Bound is considered an outlier.

# %% [markdown]
# 8.Discuss the conditions under which the binomial distribution is used.
# - The binomial distribution models the number of successes in a fixed number of independent trials of a binary (two-outcome) experiment. It is widely used in probability and statistics for discrete data.
#
# - Conditions for Using the Binomial Distribution
#   - A random variable follows a binomial distribution if it meets these four conditions:
#
#     - Fixed Number of Trials (
# 𝑛
# n)
#
#       - The experiment is repeated a set number of times.
#
#       - Example: Flipping a coin 10 times and counting the number of heads.
#
#     - Only Two Possible Outcomes (Success or Failure)
#
#       - Each trial must result in one of two mutually exclusive outcomes:
#
#       - Success (e.g., getting heads, passing a test, hitting a target)
#
#       - Failure (e.g., getting tails, failing a test, missing a target)
#
#     - Constant Probability of Success (
# 𝑝
# p)
#
#       - The probability of success remains the same across all trials.
#
#       - Example: The probability of rolling a 6 on a fair die is always
# 1
# 6
# 6
# 1
# ​
#  , regardless of previous rolls.

# %% [markdown]
# 9.Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule).
# - A normal distribution (also called a Gaussian distribution) is a bell-shaped,
#  symmetric probability distribution that describes many natural phenomena, such as heights, test scores, and IQ levels.
#
# - Properties of the Normal Distribution
#   - Symmetrical Shape
#
#     - The distribution is perfectly symmetrical around the mean (
# 𝜇
# μ).
#
#     - Mean = Median = Mode
#
#   - Bell-Shaped Curve
#
#     - Most values cluster around the mean, with fewer values appearing at the tails.
#
#     - Defined by Mean (
# 𝜇
# μ) and Standard Deviation (
# 𝜎
# σ)
#
#   - The mean (
# 𝜇
# μ) determines the center of the distribution.
#
#   - The standard deviation (
# 𝜎
# σ) controls the spread of the data.
#
#   - Total Probability = 1 (100%)
#
# The area under the curve sums to 1 (or 100%), meaning all probabilities of possible values are covered.

# %% [markdown]
# 10.Provide a real-life example of a Poisson process and calculate the probability for a specific event.
# - A Poisson process models events that occur randomly and independently over a fixed interval of time or space. The key assumptions are:
#
#   - Events occur at a constant average rate (
# 𝜆
# λ).
#
#   - Each event is independent of the others.
#
#   - Two events cannot occur at the exact same time (in an infinitesimally small interval).
#
# Example: Customer Arrivals at a Coffee Shop
# Suppose a coffee shop receives an average of 10 customers per hour (
# 𝜆
# =
# 10
# λ=10). We want to calculate the probability that exactly 7 customers arrive in an hour.
#
# The Poisson probability formula is:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝑒
# −
# 𝜆
# 𝜆
# 𝑘
# 𝑘
# !
# P(X=k)=
# k!
# e
# −λ
#  λ
# k
#
# ​
#
# Where:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# P(X=k) = Probability of exactly
# 𝑘
# k events occurring
#
# 𝜆
# λ = Average number of events (here, 10 customers per hour)
#
# 𝑘
# k = Desired number of occurrences (7 customers)
#
# 𝑒
# e = Euler's number (≈ 2.718)
#
# Calculation for
# 𝑃
# (
# 𝑋
# =
# 7
# )
# P(X=7)
# 𝑃
# (
# 𝑋
# =
# 7
# )
# =
# 𝑒
# −
# 10
# ⋅
# 10
# 7
# 7
# !
# P(X=7)=
# 7!
# e
# −10
#  ⋅10
# 7
#
# ​
#
# Let's compute this:
#
# The probability of exactly 7 customers arriving in an hour is 0.0901 (or 9.01%).

# %% [markdown]
# 11.Explain what a random variable is and differentiate between discrete and continuous random variables.
# - A random variable is a numerical outcome of a random experiment. It assigns a number to each possible outcome in a probability experiment.
#
# For example:
#
# Rolling a die → The outcome (1, 2, 3, 4, 5, or 6) is a random variable.
#
# Counting the number of customers arriving at a store → The number of arrivals is a random variable.
#
# - Discrete Random Variables
# A discrete random variable takes on a countable number of distinct values. These values are typically whole numbers (integers) and arise from counting something.
#
# Examples of Discrete Random Variables:
# Rolling a die → Possible outcomes: {1, 2, 3, 4, 5, 6}
#
# Number of customers in a queue → Can be 0, 1, 2, 3, etc., but not 2.5.
#
# Number of heads in 5 coin flips → Can be 0, 1, 2, 3, 4, or 5.
#
# ✔ Key Feature: Values are finite or countably infinite.
#
# - Continuous Random Variables
# A continuous random variable takes on an infinite number of possible values within a given range. These values usually come from measuring something.
#
# Examples of Continuous Random Variables:
# Height of students in a class → Can be 160.2 cm, 170.5 cm, etc.
#
# Temperature in a city → Can be 25.3°C, 30.8°C, etc.
#
# Time taken to complete a task → Can be 10.1 minutes, 10.5 minutes, etc.
#
# ✔ Key Feature: Values are uncountable and can take any value within a range.

# %% [markdown]
# 12.Provide an example dataset, calculate both covariance and correlation, and interpret the results.
# - ![Screenshot 2025-03-30 195934.png](data:image/png;base64,...)
#
# Step 1: Covariance Calculation
# The covariance formula is:
#
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# =
# 1
# 𝑛
# −
# 1
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# Cov(X,Y)=
# n−1
# 1
# ​
#
# i=1
# ∑
# n
# ​
#  (X
# i
# ​
#  −
# X
# ˉ
#  )(Y
# i
# ​
#  −
# Y
# ˉ
#  )
# Where:
#
# 𝑋
# X = Heights
#
# 𝑌
# Y = Weights
#
# 𝑋
# ˉ
# X
# ˉ
#   = Mean of heights
#
# 𝑌
# ˉ
# Y
# ˉ
#   = Mean of weights
#
# Correlation Calculation
# The correlation coefficient (
# 𝜌
# ρ or
# 𝑟
# r) measures the strength and direction of the relationship:
#
# 𝑟
# =
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# 𝜎
# 𝑋
# 𝜎
# 𝑌
# r=
# σ
# X
# ​
#  σ
# Y
# ​
#
# Cov(X,Y)
# ​
#
# Where:
#
# 𝜎
# 𝑋
# σ
# X
# ​
#   = Standard deviation of
# 𝑋
# X (heights)
#
# 𝜎
# 𝑌
# σ
# Y
# ​
#   = Standard deviation of
# 𝑌
# Y (weights)
#
# Covariance = 52.5
#
# A positive covariance indicates that as height increases, weight also tends to increase.
#
# However, covariance alone does not tell us the strength of the relationship.
#
# Correlation = 0.995
#
# The correlation coefficient is very close to 1, indicating a strong positive relationship between height and weight.
#
# This means that taller individuals tend to weigh more in this dataset.
